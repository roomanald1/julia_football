# %% [markdown]
# ******************************************
#
# # Premier League Data Analysis
#
# ******************************************

# %% [markdown]
# ## Setup

# %%
using Pkg
Pkg.add("StringEncodings")
Pkg.add("CSV")
Pkg.add("ZipFile")
Pkg.add("DataFrames")
using ZipFile
using CSV
using DataFrames
using StringEncodings
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.11/Project.toml`
#   No Changes to `~/.julia/environments/v1.11/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.11/Project.toml`
#   No Changes to `~/.julia/environments/v1.11/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.11/Project.toml`
#   No Changes to `~/.julia/environments/v1.11/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.11/Project.toml`
#   No Changes to `~/.julia/environments/v1.11/Manifest.toml`

# %% [markdown]
# ### Fetch the 2018/2019 Premier League Data

# %%
download("https://www.kaggle.com/api/v1/datasets/download/yusukefromjpn/england-premier-league-2018-to-2019-stats", "stats.zip")
download("https://www.kaggle.com/api/v1/datasets/download/yusukefromjpn/2018-2019-premier-league", "stats2.zip")
# Out:
# "stats2.zip"

# %%
arch = ZipFile.Reader("stats.zip")

team_file = arch.files[1]
player_file = arch.files[2]
other = arch.files[3]

team_data = read(team_file, String)
player_data = read(player_file, String)
other_data = read(other, String)

team_stats = IOBuffer(team_data)
player_stats = IOBuffer(player_data)
other_stats = IOBuffer(other_data)
# Out:
# IOBuffer(data=UInt8[...], readable=true, writable=false, seekable=true, append=false, size=25104, maxsize=Inf, ptr=1, mark=-1)

# %%
team_df = CSV.File(team_stats; normalizenames=true, delim=',', header=true) |> DataFrame
# Out:
# 380×66 DataFrame
#  Row │ timestamp   date_GMT               status    attendance  home_team_name ⋯
#      │ Int64       String31               String15  Int64       String31       ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 1533927600  Aug 10 2018 - 7:00pm   complete       74439  Manchester Uni ⋯
#    2 │ 1533987000  Aug 11 2018 - 11:30am  complete       51749  Newcastle Unit
#    3 │ 1533996000  Aug 11 2018 - 2:00pm   complete       10353  AFC Bournemout
#    4 │ 1533996000  Aug 11 2018 - 2:00pm   complete       24821  Fulham
#    5 │ 1533996000  Aug 11 2018 - 2:00pm   complete       24121  Huddersfield T ⋯
#    6 │ 1533996000  Aug 11 2018 - 2:00pm   complete       20051  Watford
#    7 │ 1534005000  Aug 11 2018 - 4:30pm   complete       31231  Wolverhampton
#    8 │ 1534077000  Aug 12 2018 - 12:30pm  complete       53235  Liverpool
#    9 │ 1534077000  Aug 12 2018 - 12:30pm  complete       30784  Southampton    ⋯
#   10 │ 1534086000  Aug 12 2018 - 3:00pm   complete       59934  Arsenal
#   11 │ 1534591800  Aug 18 2018 - 11:30am  complete       30720  Cardiff City
#   ⋮  │     ⋮                 ⋮               ⋮          ⋮                  ⋮   ⋱
#  371 │ 1557669600  May 12 2019 - 2:00pm   complete       30662  Brighton & Hov
#  372 │ 1557669600  May 12 2019 - 2:00pm   complete       21461  Burnley        ⋯
#  373 │ 1557669600  May 12 2019 - 2:00pm   complete       25433  Crystal Palace
#  374 │ 1557669600  May 12 2019 - 2:00pm   complete       24979  Fulham
#  375 │ 1557669600  May 12 2019 - 2:00pm   complete       32140  Leicester City
#  376 │ 1557669600  May 12 2019 - 2:00pm   complete       53331  Liverpool      ⋯
#  377 │ 1557669600  May 12 2019 - 2:00pm   complete       74457  Manchester Uni
#  378 │ 1557669600  May 12 2019 - 2:00pm   complete       30367  Southampton
#  379 │ 1557669600  May 12 2019 - 2:00pm   complete       60124  Tottenham Hots
#  380 │ 1557669600  May 12 2019 - 2:00pm   complete       20067  Watford        ⋯
#                                                  62 columns and 359 rows omitted

# %%
other_df = CSV.File(other_stats; normalizenames=true, delim=',', header=true) |> DataFrame
# Out:
# 20×293 DataFrame
#  Row │ team_name                   common_name              season     country ⋯
#      │ String31                    String31                 String15   String7 ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Arsenal FC                  Arsenal                  2018/2019  England ⋯
#    2 │ Tottenham Hotspur FC        Tottenham Hotspur        2018/2019  England
#    3 │ Manchester City FC          Manchester City          2018/2019  England
#    4 │ Leicester City FC           Leicester City           2018/2019  England
#    5 │ Crystal Palace FC           Crystal Palace           2018/2019  England ⋯
#    6 │ Everton FC                  Everton                  2018/2019  England
#    7 │ Burnley FC                  Burnley                  2018/2019  England
#    8 │ Southampton FC              Southampton              2018/2019  England
#    9 │ AFC Bournemouth             AFC Bournemouth          2018/2019  England ⋯
#   10 │ Manchester United FC        Manchester United        2018/2019  England
#   11 │ Liverpool FC                Liverpool                2018/2019  England
#   12 │ Chelsea FC                  Chelsea                  2018/2019  England
#   13 │ West Ham United FC          West Ham United          2018/2019  England ⋯
#   14 │ Watford FC                  Watford                  2018/2019  England
#   15 │ Newcastle United FC         Newcastle United         2018/2019  England
#   16 │ Cardiff City FC             Cardiff City             2018/2019  Wales
#   17 │ Fulham FC                   Fulham                   2018/2019  England ⋯
#   18 │ Brighton & Hove Albion FC   Brighton & Hove Albion   2018/2019  England
#   19 │ Huddersfield Town FC        Huddersfield Town        2018/2019  England
#   20 │ Wolverhampton Wanderers FC  Wolverhampton Wanderers  2018/2019  England
#                                                              289 columns omitted

# %%
player_df = CSV.File(player_stats; normalizenames=true, delim=',', header=true) |> DataFrame
# Out:
# 561×47 DataFrame
#  Row │ full_name                    age    birthday   birthday_GMT  league     ⋯
#      │ String                       Int64  Int64      String15      String15   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Aaron Cresswell                 32  629712000  1989/12/15    Premier Le ⋯
#    2 │ Aaron Lennon                    35  545554800  1987/4/16     Premier Le
#    3 │ Aaron Mooy                      32  653382000  1990/9/15     Premier Le
#    4 │ Aaron Ramsey                    31  662198400  1990/12/26    Premier Le
#    5 │ Aaron Rowe                      22  968310000  2000/9/7      Premier Le ⋯
#    6 │ Aaron Wan-Bissaka               24  880531200  1997/11/26    Premier Le
#    7 │ Abdelhamid Sabiri               25  849168000  1996/11/28    Premier Le
#    8 │ Abdoulaye Doucouré              29  725875200  1993/1/1      Premier Le
#    9 │ Aboubakar Kamara                27  794563200  1995/3/7      Premier Le ⋯
#   10 │ Adalberto Peñaranda Maestre     25  865062000  1997/5/31     Premier Le
#   11 │ Adam Lallana                    34  579250800  1988/5/10     Premier Le
#   ⋮  │              ⋮                 ⋮        ⋮           ⋮              ⋮    ⋱
#  552 │ Willy Caballero                 41  370508400  1981/9/28     Premier Le
#  553 │ Xherdan Shaqiri                 31  687078000  1991/10/10    Premier Le ⋯
#  554 │ Yan Valery                      23  919670400  1999/2/22     Premier Le
#  555 │ Yerry Mina                      28  780303600  1994/9/23     Premier Le
#  556 │ Yoshinori Muto                  30  711183600  1992/7/15     Premier Le
#  557 │ Youri Tielemans                 25  862988400  1997/5/7      Premier Le ⋯
#  558 │ Yves Bissouma                   26  841388400  1996/8/30     Premier Le
#  559 │ Zechariah Medley                22  962953200  2000/7/7      Premier Le
#  560 │ Zeze  Steven Sessegnon          22  958633200  2000/5/18     Premier Le
#  561 │ Łukasz Fabiański                37  482659200  1985/4/18     Premier Le ⋯
#                                                  43 columns and 540 rows omitted

# %% [markdown]
# ******************************************
#
#
# # Stadium that witnessed the most goals
#
#
# ******************************************

# %%
df_group = groupby(team_df, ["stadium_name"])
# Out:
# GroupedDataFrame with 21 groups based on key: stadium_name
# First Group (19 rows): stadium_name = "Old Trafford (Manchester)"
#  Row │ timestamp   date_GMT              status    attendance  home_team_name  ⋯
#      │ Int64       String31              String15  Int64       String31        ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 1533927600  Aug 10 2018 - 7:00pm  complete       74439  Manchester Unit ⋯
#    2 │ 1535396400  Aug 27 2018 - 7:00pm  complete       74400  Manchester Unit
#    3 │ 1537624800  Sep 22 2018 - 2:00pm  complete       74489  Manchester Unit
#    4 │ 1538843400  Oct 06 2018 - 4:30pm  complete       74519  Manchester Unit
#    5 │ 1540742400  Oct 28 2018 - 4:00pm  complete       74525  Manchester Unit ⋯
#   ⋮  │     ⋮                ⋮               ⋮          ⋮               ⋮       ⋱
#   15 │ 1553958000  Mar 30 2019 - 3:00pm  complete       74543  Manchester Unit
#   16 │ 1555173000  Apr 13 2019 - 4:30pm  complete       74478  Manchester Unit
#   17 │ 1556132400  Apr 24 2019 - 7:00pm  complete       74431  Manchester Unit
#   18 │ 1556465400  Apr 28 2019 - 3:30pm  complete       74526  Manchester Unit ⋯
#   19 │ 1557669600  May 12 2019 - 2:00pm  complete       74457  Manchester Unit
#                                                    62 columns and 9 rows omitted
# ⋮
# Last Group (5 rows): stadium_name = "Tottenham Hotspur Stadium (London)"
#  Row │ timestamp   date_GMT               status    attendance  home_team_name ⋯
#      │ Int64       String31               String15  Int64       String31       ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 1554317100  Apr 03 2019 - 6:45pm   complete       59215  Tottenham Hots ⋯
#    2 │ 1555155000  Apr 13 2019 - 11:30am  complete       58308  Tottenham Hots
#   ⋮  │     ⋮                 ⋮               ⋮          ⋮               ⋮      ⋱
#    5 │ 1557669600  May 12 2019 - 2:00pm   complete       60124  Tottenham Hots
#                                                    62 columns and 2 rows omitted

# %%
goals = combine(df_group, "home_team_goal_count" => sum, "away_team_goal_count" => sum)
# Out:
# 21×3 DataFrame
#  Row │ stadium_name                       home_team_goal_count_sum  away_team_ ⋯
#      │ String                             Int64                     Int64      ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Old Trafford (Manchester)                                33             ⋯
#    2 │ St. James' Park (Newcastle upon …                        24
#    3 │ Vitality Stadium (Bournemouth- D…                        30
#    4 │ Craven Cottage (London)                                  22
#    5 │ John Smith's Stadium (Huddersfie…                        10             ⋯
#    6 │ Vicarage Road (Watford)                                  26
#    7 │ Molineux Stadium (Wolverhampton-…                        28
#    8 │ Anfield (Liverpool)                                      55
#    9 │ St. Mary's Stadium (Southampton-…                        27             ⋯
#   10 │ Emirates Stadium (London)                                42
#   11 │ Cardiff City Stadium (Cardiff (C…                        21
#   12 │ Goodison Park (Liverpool)                                30
#   13 │ King Power Stadium (Leicester- L…                        24             ⋯
#   14 │ Wembley Stadium (London)                                 25
#   15 │ London Stadium (London)                                  32
#   16 │ Stamford Bridge (London)                                 39
#   17 │ Turf Moor (Burnley)                                      24             ⋯
#   18 │ Etihad Stadium (Manchester)                              57
#   19 │ The American Express Community S…                        19
#   20 │ Selhurst Park (London)                                   19
#   21 │ Tottenham Hotspur Stadium (Londo…                         9             ⋯
#                                                                 1 column omitted

# %%
stadium_goals = combine(goals, "stadium_name", ["home_team_goal_count_sum", "away_team_goal_count_sum"] => (a,b) -> a + b)
# Out:
# 21×2 DataFrame
#  Row │ stadium_name                       home_team_goal_count_sum_away_team_g ⋯
#      │ String                             Int64                                ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Old Trafford (Manchester)                                               ⋯
#    2 │ St. James' Park (Newcastle upon …
#    3 │ Vitality Stadium (Bournemouth- D…
#    4 │ Craven Cottage (London)
#    5 │ John Smith's Stadium (Huddersfie…                                       ⋯
#    6 │ Vicarage Road (Watford)
#    7 │ Molineux Stadium (Wolverhampton-…
#    8 │ Anfield (Liverpool)
#    9 │ St. Mary's Stadium (Southampton-…                                       ⋯
#   10 │ Emirates Stadium (London)
#   11 │ Cardiff City Stadium (Cardiff (C…
#   12 │ Goodison Park (Liverpool)
#   13 │ King Power Stadium (Leicester- L…                                       ⋯
#   14 │ Wembley Stadium (London)
#   15 │ London Stadium (London)
#   16 │ Stamford Bridge (London)
#   17 │ Turf Moor (Burnley)                                                     ⋯
#   18 │ Etihad Stadium (Manchester)
#   19 │ The American Express Community S…
#   20 │ Selhurst Park (London)
#   21 │ Tottenham Hotspur Stadium (Londo…                                       ⋯
#                                                                 1 column omitted

# %% [markdown]
# ## Result

# %%
rename!(sort(stadium_goals, [order("home_team_goal_count_sum_away_team_goal_count_sum_function", rev=true)]), ["Stadium", "Number Of Goals"])
# Out:
# 21×2 DataFrame
#  Row │ Stadium                            Number Of Goals
#      │ String                             Int64
# ─────┼────────────────────────────────────────────────────
#    1 │ Etihad Stadium (Manchester)                     69
#    2 │ Anfield (Liverpool)                             65
#    3 │ Cardiff City Stadium (Cardiff (C…               59
#    4 │ London Stadium (London)                         59
#    5 │ Old Trafford (Manchester)                       58
#    6 │ Craven Cottage (London)                         58
#    7 │ Emirates Stadium (London)                       58
#    8 │ St. Mary's Stadium (Southampton-…               57
#    9 │ Turf Moor (Burnley)                             56
#   10 │ Vitality Stadium (Bournemouth- D…               55
#   11 │ Vicarage Road (Watford)                         54
#   12 │ Goodison Park (Liverpool)                       51
#   13 │ Stamford Bridge (London)                        51
#   14 │ St. James' Park (Newcastle upon …               49
#   15 │ Molineux Stadium (Wolverhampton-…               49
#   16 │ The American Express Community S…               47
#   17 │ King Power Stadium (Leicester- L…               44
#   18 │ Selhurst Park (London)                          42
#   19 │ John Smith's Stadium (Huddersfie…               41
#   20 │ Wembley Stadium (London)                        38
#   21 │ Tottenham Hotspur Stadium (Londo…               12

# %% [markdown]
# # Most card happy ref

# %%
ref_group = groupby(team_df, ["referee"])
# Out:
# GroupedDataFrame with 18 groups based on key: referee
# First Group (27 rows): referee = "Andre Marriner"
#  Row │ timestamp   date_GMT               status    attendance  home_team_name ⋯
#      │ Int64       String31               String15  Int64       String31       ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 1533927600  Aug 10 2018 - 7:00pm   complete       74439  Manchester Uni ⋯
#    2 │ 1534681800  Aug 19 2018 - 12:30pm  complete       54021  Manchester Cit
#    3 │ 1535900400  Sep 02 2018 - 3:00pm   complete       20141  Watford
#    4 │ 1537101000  Sep 16 2018 - 12:30pm  complete       30406  Wolverhampton
#    5 │ 1537624800  Sep 22 2018 - 2:00pm   complete       25679  Crystal Palace ⋯
#    6 │ 1538238600  Sep 29 2018 - 4:30pm   complete       40625  Chelsea
#    7 │ 1538834400  Oct 06 2018 - 2:00pm   complete       32007  Leicester City
#   ⋮  │     ⋮                 ⋮               ⋮          ⋮                  ⋮   ⋱
#   22 │ 1552219200  Mar 10 2019 - 12:00pm  complete       53310  Liverpool
#   23 │ 1554317100  Apr 03 2019 - 6:45pm   complete       59215  Tottenham Hots ⋯
#   24 │ 1555440300  Apr 16 2019 - 6:45pm   complete       30226  Brighton & Hov
#   25 │ 1556132400  Apr 24 2019 - 7:00pm   complete       74431  Manchester Uni
#   26 │ 1556995500  May 04 2019 - 6:45pm   complete       52206  Newcastle Unit
#   27 │ 1557669600  May 12 2019 - 2:00pm   complete       60124  Tottenham Hots ⋯
#                                                   62 columns and 14 rows omitted
# ⋮
# Last Group (2 rows): referee = "Andy Madley"
#  Row │ timestamp   date_GMT              status    attendance  home_team_name  ⋯
#      │ Int64       String31              String15  Int64       String31        ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#   ⋮  │     ⋮                ⋮               ⋮          ⋮                 ⋮     ⋱
#                                                    62 columns and 2 rows omitted

# %%
cards_per_ref = combine(ref_group, "home_team_yellow_cards" => sum, "away_team_yellow_cards" => sum, "home_team_red_cards" => sum, "away_team_red_cards" => sum)
# Out:
# 18×5 DataFrame
#  Row │ referee          home_team_yellow_cards_sum  away_team_yellow_cards_sum ⋯
#      │ String15         Int64                       Int64                      ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Andre Marriner                           33                          43 ⋯
#    2 │ Martin Atkinson                          38                          53
#    3 │ Kevin Friend                             48                          44
#    4 │ Mike Dean                                64                          70
#    5 │ Chris Kavanagh                           39                          36 ⋯
#    6 │ Jonathan Moss                            47                          50
#    7 │ Craig Pawson                             46                          46
#    8 │ Anthony Taylor                           57                          45
#    9 │ Graham Scott                             14                          24 ⋯
#   10 │ Michael Oliver                           35                          50
#   11 │ Lee Mason                                30                          33
#   12 │ Stuart Attwell                           31                          32
#   13 │ Paul Tierney                             37                          45 ⋯
#   14 │ Lee Probert                              20                          28
#   15 │ David Coote                              16                          19
#   16 │ Roger East                               23                          21
#   17 │ Simon Hooper                              9                          11 ⋯
#   18 │ Andy Madley                               0                           2
#                                                                2 columns omitted

# %%
ref_cards = combine(cards_per_ref, "referee", ["home_team_yellow_cards_sum", "away_team_yellow_cards_sum", "home_team_red_cards_sum", "away_team_red_cards_sum"] => (a,b, c , d) -> a + b + c + d)
# Out:
# 18×2 DataFrame
#  Row │ referee          home_team_yellow_cards_sum_away_team_yellow_cards_sum_ ⋯
#      │ String15         Int64                                                  ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Andre Marriner                                                          ⋯
#    2 │ Martin Atkinson
#    3 │ Kevin Friend
#    4 │ Mike Dean
#    5 │ Chris Kavanagh                                                          ⋯
#    6 │ Jonathan Moss
#    7 │ Craig Pawson
#    8 │ Anthony Taylor
#    9 │ Graham Scott                                                            ⋯
#   10 │ Michael Oliver
#   11 │ Lee Mason
#   12 │ Stuart Attwell
#   13 │ Paul Tierney                                                            ⋯
#   14 │ Lee Probert
#   15 │ David Coote
#   16 │ Roger East
#   17 │ Simon Hooper                                                            ⋯
#   18 │ Andy Madley
#                                                                 1 column omitted

# %%
rename!(sort(ref_cards, [order("home_team_yellow_cards_sum_away_team_yellow_cards_sum_etc_function", rev=true)]), ["Ref", "Number Of Cards"])
# Out:
# 18×2 DataFrame
#  Row │ Ref              Number Of Cards
#      │ String15         Int64
# ─────┼──────────────────────────────────
#    1 │ Mike Dean                    144
#    2 │ Anthony Taylor               103
#    3 │ Jonathan Moss                102
#    4 │ Craig Pawson                  99
#    5 │ Kevin Friend                  95
#    6 │ Martin Atkinson               92
#    7 │ Michael Oliver                92
#    8 │ Paul Tierney                  83
#    9 │ Andre Marriner                79
#   10 │ Chris Kavanagh                77
#   11 │ Lee Mason                     64
#   12 │ Stuart Attwell                64
#   13 │ Lee Probert                   52
#   14 │ Roger East                    44
#   15 │ Graham Scott                  39
#   16 │ David Coote                   35
#   17 │ Simon Hooper                  20
#   18 │ Andy Madley                    2

# %% [markdown]
# # Beat the bookies - Which team Won most against the bookmakers odds

# %% [markdown]
# # Bookies Best Bet - Which team had the most results closest to the bookmakers predictions

# %% [markdown]
# # Goal Time / 90 mins

# %% [markdown]
# # Goal Time / 90 mins / Game week

# %% [markdown]
# # Team with most non Sat 3pm kickoffs

# %%
Pkg.add(PackageSpec(name="PyCall", rev="master"))
# Out:
#      Cloning git-repo `https://github.com/JuliaPy/PyCall.jl.git`
# git-repo `https://github.com/JuliaPy/PyCall.jl.git`
#    Resolving package versions...
#     Updating `~/.julia/environments/v1.11/Project.toml`
#   [438e738f] ~ PyCall v1.96.4 ⇒ v1.96.4 `https://github.com/JuliaPy/PyCall.jl.git#master`
#  `~/.julia/environments/v1.11/Manifest.toml`
#   [438e738f] ~ PyCall v1.96.4 ⇒ v1.96.4 `https://github.com/JuliaPy/PyCall.jl.git#master`
# PyCall → `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/6ca471a8b5ec088665540d54ea93137d4f8f93f0/build.log`
# Precompiling project...
#   17898.7 ms  ✓ PyCall
#    4958.2 ms  ✓ PyPlot
#   2 dependencies successfully precompiled in 24 seconds. 287 already precompiled.

# %%
Pkg.build("PyCall")
# Out:
#     Building Conda ─→ `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/b19db3927f0db4151cb86d073689f2428e524576/build.log`
#     Building PyCall → `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/6ca471a8b5ec088665540d54ea93137d4f8f93f0/build.log`

# %%
using PyCall 
Pkg.add("Conda")
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.11/Project.toml`
#   No Changes to `~/.julia/environments/v1.11/Manifest.toml`

# %%
using Conda
Conda.add("mplsoccer")
# Out:
# [ Info: Running `conda install -y mplsoccer` in root environment
# Channels:
#  - conda-forge
# Platform: osx-64
# doneecting package metadata (repodata.json): ...working...
# doneing environment: ...working...
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.3
#     latest version: 25.1.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
# ## Package Plan ##
#
#   environment location: /Users/ronnieday/.julia/conda/3/x86_64
#
#   added / updated specs:
#     - mplsoccer
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     mplsoccer-1.4.0            |     pyhd8ed1ab_0          72 KB  conda-forge
#     pandas-2.2.2               |  py312h1171441_1        14.0 MB  conda-forge
#     patsy-1.0.1                |     pyhd8ed1ab_1         182 KB  conda-forge
#     python-tzdata-2025.1       |     pyhd8ed1ab_0         140 KB  conda-forge
#     scipy-1.15.2               |  py312hd04560d_0        14.8 MB  conda-forge
#     seaborn-0.13.2             |       hd8ed1ab_3           7 KB  conda-forge
#     seaborn-base-0.13.2        |     pyhd8ed1ab_3         223 KB  conda-forge
#     statsmodels-0.14.4         |  py312h3a11e2b_0        11.2 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        40.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   mplsoccer          conda-forge/noarch::mplsoccer-1.4.0-pyhd8ed1ab_0
#   pandas             conda-forge/osx-64::pandas-2.2.2-py312h1171441_1
#   patsy              conda-forge/noarch::patsy-1.0.1-pyhd8ed1ab_1
#   python-tzdata      conda-forge/noarch::python-tzdata-2025.1-pyhd8ed1ab_0
#   scipy              conda-forge/osx-64::scipy-1.15.2-py312hd04560d_0
#   seaborn            conda-forge/noarch::seaborn-0.13.2-hd8ed1ab_3
#   seaborn-base       conda-forge/noarch::seaborn-base-0.13.2-pyhd8ed1ab_3
#   statsmodels        conda-forge/osx-64::statsmodels-0.14.4-py312h3a11e2b_0
#
#
#
# scipy-1.15.2         | 14.8 MB   |                                      |   0%
# pandas-2.2.2         | 14.0 MB   |                                      |   0%
#
# statsmodels-0.14.4   | 11.2 MB   |                                      |   0%
#
#
# seaborn-base-0.13.2  | 223 KB    |                                      |   0%
#
#
#
# patsy-1.0.1          | 182 KB    |                                      |   0%
#
#
#
#
# python-tzdata-2025.1 | 140 KB    |                                      |   0%
#
#
#
#
#
# mplsoccer-1.4.0      | 72 KB     |                                      |   0%
#
#
#
#
#
#
# seaborn-0.13.2       | 7 KB      |                                      |   0%
#
#
# seaborn-base-0.13.2  | 223 KB    | ####################7                |  58%
#
#
#
# patsy-1.0.1          | 182 KB    | ###1                                 |   9%
# pandas-2.2.2         | 14.0 MB   |                                      |   0%
#
#
# seaborn-base-0.13.2  | 223 KB    | #################################### | 100%
#
#
#
# patsy-1.0.1          | 182 KB    | #################################### | 100%
#
#
#
#
# python-tzdata-2025.1 | 140 KB    | ####1                                |  11%
#
#
#
#
# python-tzdata-2025.1 | 140 KB    | #################################### | 100%
# scipy-1.15.2         | 14.8 MB   |                                      |   0%
#
# statsmodels-0.14.4   | 11.2 MB   |                                      |   0%
#
#
# seaborn-base-0.13.2  | 223 KB    | #################################### | 100%
#
#
#
# patsy-1.0.1          | 182 KB    | #################################### | 100%
#
#
#
# patsy-1.0.1          | 182 KB    | #################################### | 100%
#
#
#
#
#
#
# seaborn-0.13.2       | 7 KB      | #################################### | 100%
#
#
#
#
#
#
# seaborn-0.13.2       | 7 KB      | #################################### | 100%
#
#
#
#
#
#
# seaborn-0.13.2       | 7 KB      | #################################### | 100%
#
#
#
#
#
# mplsoccer-1.4.0      | 72 KB     | #######9                             |  22%
# scipy-1.15.2         | 14.8 MB   |                                      |   0%
#
# statsmodels-0.14.4   | 11.2 MB   | 4                                    |   1%
# pandas-2.2.2         | 14.0 MB   | ###3                                 |   9%
#
# scipy-1.15.2         | 14.8 MB   | 3                                    |   1%
# pandas-2.2.2         | 14.0 MB   | ####9                                |  14%
#
# scipy-1.15.2         | 14.8 MB   | 8                                    |   2%
#
#
#
#
# python-tzdata-2025.1 | 140 KB    | #################################### | 100%
#
#
#
#
# python-tzdata-2025.1 | 140 KB    | #################################### | 100%
# pandas-2.2.2         | 14.0 MB   | ######                               |  17%
#
#
#
#
#
# mplsoccer-1.4.0      | 72 KB     | ###############9                     |  44%
#
#
#
#
#
# mplsoccer-1.4.0      | 72 KB     | #################################### | 100%
#
#
#
#
#
# mplsoccer-1.4.0      | 72 KB     | #################################### | 100%
#
#
#
#
#
# scipy-1.15.2         | 14.8 MB   | #                                    |   3%
# pandas-2.2.2         | 14.0 MB   | ######9                              |  19%
#
# scipy-1.15.2         | 14.8 MB   | ##                                   |   6%
# pandas-2.2.2         | 14.0 MB   | #########8                           |  27%
#
# scipy-1.15.2         | 14.8 MB   | ##4                                  |   7%
# pandas-2.2.2         | 14.0 MB   | ###########3                         |  32%
#
# scipy-1.15.2         | 14.8 MB   | ##8                                  |   8%
#
# statsmodels-0.14.4   | 11.2 MB   | ######5                              |  18%
# pandas-2.2.2         | 14.0 MB   | ############6                        |  35%
#
# scipy-1.15.2         | 14.8 MB   | ###2                                 |   9%
# pandas-2.2.2         | 14.0 MB   | #############7                       |  38%
# scipy-1.15.2         | 14.8 MB   | ###5                                 |  10%
#
# statsmodels-0.14.4   | 11.2 MB   | ########1                            |  23%
# scipy-1.15.2         | 14.8 MB   | ####4                                |  12%
#
# statsmodels-0.14.4   | 11.2 MB   | ##########1                          |  28%
# scipy-1.15.2         | 14.8 MB   | ####8                                |  14%
#
# statsmodels-0.14.4   | 11.2 MB   | ###########2                         |  31%
# scipy-1.15.2         | 14.8 MB   | #####3                               |  15%
#
# statsmodels-0.14.4   | 11.2 MB   | ############2                        |  34%
# scipy-1.15.2         | 14.8 MB   | #####6                               |  16%
#
# statsmodels-0.14.4   | 11.2 MB   | #############1                       |  36%
# scipy-1.15.2         | 14.8 MB   | ######                               |  17%
#
# statsmodels-0.14.4   | 11.2 MB   | #############9                       |  39%
# scipy-1.15.2         | 14.8 MB   | ######4                              |  18%
#
# statsmodels-0.14.4   | 11.2 MB   | ##############8                      |  41%
# scipy-1.15.2         | 14.8 MB   | ######8                              |  19%
#
# statsmodels-0.14.4   | 11.2 MB   | ###############6                     |  43%
# scipy-1.15.2         | 14.8 MB   | #######1                             |  20%
#
# statsmodels-0.14.4   | 11.2 MB   | ################4                    |  46%
# scipy-1.15.2         | 14.8 MB   | #######5                             |  21%
#
# statsmodels-0.14.4   | 11.2 MB   | #################2                   |  48%
# scipy-1.15.2         | 14.8 MB   | #######8                             |  22%
# pandas-2.2.2         | 14.0 MB   | ##########################4          |  73%
#
# scipy-1.15.2         | 14.8 MB   | ########1                            |  23%
# pandas-2.2.2         | 14.0 MB   | ###########################4         |  76%
#
# scipy-1.15.2         | 14.8 MB   | ########5                            |  24%
# pandas-2.2.2         | 14.0 MB   | ############################3        |  79%
#
# scipy-1.15.2         | 14.8 MB   | ########8                            |  25%
# pandas-2.2.2         | 14.0 MB   | #############################3       |  82%
#
# scipy-1.15.2         | 14.8 MB   | #########2                           |  26%
# pandas-2.2.2         | 14.0 MB   | ##############################3      |  84%
#
# scipy-1.15.2         | 14.8 MB   | #########5                           |  27%
# pandas-2.2.2         | 14.0 MB   | ###############################2     |  87%
#
# scipy-1.15.2         | 14.8 MB   | #########9                           |  28%
# pandas-2.2.2         | 14.0 MB   | ################################2    |  90%
#
# scipy-1.15.2         | 14.8 MB   | ##########2                          |  28%
# pandas-2.2.2         | 14.0 MB   | #################################1   |  92%
#
# scipy-1.15.2         | 14.8 MB   | ##########5                          |  29%
# pandas-2.2.2         | 14.0 MB   | ##################################1  |  95%
#
# scipy-1.15.2         | 14.8 MB   | ##########9                          |  30%
# pandas-2.2.2         | 14.0 MB   | ###################################1 |  98%
#
# scipy-1.15.2         | 14.8 MB   | ###########2                         |  31%
# pandas-2.2.2         | 14.0 MB   | #################################### | 100%
#
# scipy-1.15.2         | 14.8 MB   | ###########6                         |  32%
#
# scipy-1.15.2         | 14.8 MB   | ############                         |  33%
#
# scipy-1.15.2         | 14.8 MB   | ############4                        |  35%
#
# scipy-1.15.2         | 14.8 MB   | ############9                        |  36%
#
# scipy-1.15.2         | 14.8 MB   | #############5                       |  38%
#
# scipy-1.15.2         | 14.8 MB   | ##############                       |  39%
#
# scipy-1.15.2         | 14.8 MB   | ##############7                      |  41%
#
# scipy-1.15.2         | 14.8 MB   | ###############2                     |  42%
#
# scipy-1.15.2         | 14.8 MB   | ################                     |  45%
#
# scipy-1.15.2         | 14.8 MB   | #################################### | 100%
# pandas-2.2.2         | 14.0 MB   | #################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                                 done
# donearing transaction: -
# donefying transaction: /
# doneuting transaction: -

# %%
mplsoccer = pyimport("mplsoccer")
# Out:
# PyObject <module 'mplsoccer' from '/Users/ronnieday/.julia/conda/3/x86_64/lib/python3.12/site-packages/mplsoccer/__init__.py'>

# %%
# Out:
# (PyObject                                         id  ...  foul_won_advantage
# 0     8eb54fd1-3b77-4de8-a6eb-63cb080010e7  ...                 NaN
# 1     dc677ade-3585-44c9-a377-c795a65c6310  ...                 NaN
# 2     de4c3384-3748-46b1-b6f0-6d7fd5ed41ab  ...                 NaN
# 3     206bb9ff-6848-4c98-8b81-797aaf24192b  ...                 NaN
# 4     a10ce602-229f-4c8a-8c61-95f8e7438a4a  ...                 NaN
# ...                                    ...  ...                 ...
# 4321  5aa430c2-2d96-472b-8e5e-abaf0127184a  ...                 NaN
# 4322  073d145a-d793-40b1-8be9-587c84e16a28  ...                 NaN
# 4323  9d814a56-cafc-49ac-b375-6e089236e065  ...                 NaN
# 4324  c4f738ea-1af5-4694-9264-40e35ac7972c  ...                 NaN
# 4325  f1c9fc85-e2ce-4fbc-947b-9b5d26cd7821  ...                 NaN
#
# [4326 rows x 69 columns], PyObject       match_id  ... type_name_related
# 0        18236  ...        Half Start
# 1        18236  ...        Half Start
# 2        18236  ...      Ball Receipt
# 3        18236  ...              Pass
# 4        18236  ...              Pass
# ...        ...  ...               ...
# 6458     18236  ...             Carry
# 6462     18236  ...             Carry
# 6464     18236  ...             Carry
# 6468     18236  ...             Carry
# 6469     18236  ...             Carry
#
# [8642 rows x 7 columns], PyObject      teammate  match_id  ...            position_name  event_freeze_id
# 0       False     18236  ...               Right Back                1
# 1       False     18236  ...               Right Wing                2
# 2        True     18236  ...               Right Wing                3
# 3        True     18236  ...                Left Back                4
# 4        True     18236  ...  Left Defensive Midfield                5
# ..        ...       ...  ...                      ...              ...
# 280     False     18236  ...                Left Back                5
# 281     False     18236  ...         Left Center Back                6
# 282     False     18236  ...        Right Center Back                7
# 283     False     18236  ...               Right Back                8
# 284     False     18236  ...               Goalkeeper                9
#
# [285 rows x 10 columns], PyObject     jersey_number  match_id  ...          position_name  event_tactics_id
# 0               1     18236  ...             Goalkeeper                 1
# 1               2     18236  ...             Right Back                 2
# 2              14     18236  ...      Right Center Back                 3
# 3               3     18236  ...       Left Center Back                 4
# 4              22     18236  ...              Left Back                 5
# ..            ...       ...  ...                    ...               ...
# 83              6     18236  ...  Right Center Midfield                 7
# 84              8     18236  ...   Left Center Midfield                 8
# 85             17     18236  ...             Right Wing                 9
# 86             15     18236  ...              Left Wing                10
# 87             10     18236  ...         Center Forward                11
#
# [88 rows x 8 columns])

# %%
result = mplsoccer.Sbopen().match(competition_id=2, season_id=27)

# exploring the data
result
# Out:
# PyObject      match_id match_date  ... referee_country_id  referee_country_name
# 0     3754058 2016-01-02  ...                 68               England
# 1     3754245 2015-10-17  ...                 68               England
# 2     3754136 2015-12-19  ...                 68               England
# 3     3754037 2016-04-30  ...                 68               England
# 4     3754039 2016-02-13  ...                 68               England
# ..        ...        ...  ...                ...                   ...
# 375   3754020 2015-08-17  ...                 68               England
# 376   3754267 2015-08-15  ...                 68               England
# 377   3754141 2015-08-09  ...                 68               England
# 378   3754128 2015-08-08  ...                 68               England
# 379   3754078 2015-08-08  ...                 68               England
#
# [380 rows x 52 columns]

# %%
df_event, df_related, df_freeze, df_tactics = mplsoccer.Sbopen().event(3754058)

df_event
# Out:
# PyObject                                         id  ...  foul_won_penalty
# 0     9153e9f4-f69c-4e04-8f64-505592e212cd  ...               NaN
# 1     3fbcf4e7-94d1-485a-be85-fd26a6af0318  ...               NaN
# 2     06a9a4dc-d9c9-40f6-bd89-437ba7fe682d  ...               NaN
# 3     100362ee-9311-4187-bd8a-0201d9db2565  ...               NaN
# 4     2ca23eea-a984-47e4-8243-8f00880ad1c9  ...               NaN
# ...                                    ...  ...               ...
# 3571  20baabc3-44a5-4792-8336-60dc513cc0bd  ...               NaN
# 3572  3196324d-cf4d-4d9c-92b7-5b1cac9a5910  ...               NaN
# 3573  3052795e-42ae-4543-b039-c52157c92ce6  ...               NaN
# 3574  3371e127-bdb0-45d1-84c4-eb86c918af6b  ...               NaN
# 3575  385145e8-fec7-401e-8ad0-55e3e3d1f8ff  ...               NaN
#
# [3576 rows x 71 columns]
